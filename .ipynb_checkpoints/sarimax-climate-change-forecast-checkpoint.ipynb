# %%
from pandas import read_csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
import statsmodels.api as sm
import math
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller

import itertools
import warnings

# %%
#http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#https://www.kaggle.com/poiupoiu/how-to-use-sarimax
#https://www.kaggle.com/berhag/co2-emission-forecast-with-python-seasonal-arima
#https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-arima-in-python-3

# %% [markdown]
# ## Reading and preprocessing the data

# %% [markdown]
# ### NASA GISTEMP Global Means

# %%
glb = read_csv('weather_data/GLB.Ts.csv', skiprows=1)
glb.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.76 -0.35 -0.42 -0.60 -0.30 -0.42 -0.41  0.13 -0.44 -0.60 -0.45
# 1  1881 -0.74 -0.56 -0.31 -0.21  0.02 -1.05 -0.47 -0.19 -0.29 -0.42 -0.50
# 2  1882  0.18 -0.05 -0.03 -0.54 -0.33 -0.97 -0.66 -0.06 -0.02 -0.25 -0.34
# 3  1883 -0.62 -0.89 -0.40 -0.26 -0.30  0.50  0.04 -0.10 -0.40 -0.51 -0.63
# 4  1884 -0.56 -0.30 -0.36 -0.90 -1.16 -0.79 -0.81  0.19 -0.33 -0.73 -0.78
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.47 -0.43   ***   *** -0.44 -0.24 -0.50
# 1 -0.09 -0.40  -.43  -.59 -0.16 -0.57 -0.40
# 2 -0.62 -0.31  -.26   .01 -0.30 -0.56 -0.20
# 3 -0.33 -0.32  -.35  -.71 -0.32  0.15 -0.51
# 4 -0.97 -0.63  -.57  -.40 -0.81 -0.47 -0.61

# %%
#https://data.giss.nasa.gov/gistemp/
def preprocess_temp_anomaly(anomaly):
    
    col_names =  ['DateTime', 'anomaly']
    glb_formatted = pd.DataFrame(columns = col_names)
    
    at = 0
    for index, row in glb.iterrows():
        i = 0
        months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
        for r in row[1:13]:
            date = pd.to_datetime(str(row['Year']) + '-' + months[i])
            value = r
            glb_formatted.loc[at] = [date, value]
            at = at + 1
            i = i + 1
        i= 1
    
    glb_formatted = glb_formatted.set_index(['DateTime'])
    
    return glb_formatted


glb_formatted = preprocess_temp_anomaly(glb)
glb_formatted.head()
# Out:
#             anomaly
# DateTime
# 1880-01-01    -0.76
# 1880-02-01    -0.35
# 1880-03-01    -0.42
# 1880-04-01    -0.60
# 1880-05-01    -0.30

# %% [markdown]
# ### Monthly mean carbon dioxide at Mauna Loa Observatory, Hawaii

# %%
columns= ['Year', 'Month', 'Excel', 'Date', 'CO2', 'sesonalCO2', 'FIT','sesonalFIT', 'CO2filled', 'seasonalCO2filled']

maunaloa = read_csv('weather_data/maunaloa.csv', skiprows=57, header=None, names=columns)

maunaloa['DateTime']  = pd.to_datetime(maunaloa.Year.map(str) + '-' + maunaloa.Month.map(str))
maunaloa = maunaloa.set_index(['DateTime'])

maunaloa.head()
# Out:
#             Year  Month  Excel       Date     CO2  sesonalCO2     FIT  \
# DateTime
# 1958-01-01  1958      1  21200  1958.0411  -99.99      -99.99  -99.99
# 1958-02-01  1958      2  21231  1958.1260  -99.99      -99.99  -99.99
# 1958-03-01  1958      3  21259  1958.2027  315.70      314.43  316.19
# 1958-04-01  1958      4  21290  1958.2877  317.45      315.15  317.30
# 1958-05-01  1958      5  21320  1958.3699  317.51      314.72  317.85
#
#             sesonalFIT  CO2filled  seasonalCO2filled
# DateTime
# 1958-01-01      -99.99     -99.99             -99.99
# 1958-02-01      -99.99     -99.99             -99.99
# 1958-03-01      314.90     315.70             314.43
# 1958-04-01      314.98     317.45             315.15
# 1958-05-01      315.06     317.51             314.72

# %%
maunaloaFilled = maunaloa[['CO2filled', 'seasonalCO2filled']].copy()
maunaloaFilled.replace(to_replace=[-99.99], value=np.nan, inplace=True)

# %% [markdown]
# ### The Oceanic Niño Index (ONI)

# %%
#https://data.humdata.org/dataset/monthly-oceanic-nino-index-oni
#https://origin.cpc.ncep.noaa.gov/products/analysis_monitoring/ensostuff/detrend.nino34.ascii.txt

# %%
enso = read_csv('weather_data/ONIindex.csv',delim_whitespace=True)

# %%
enso['DateTime'] = pd.to_datetime(enso.YR.map(str) + '-' + enso.MON.map(str))
enso = enso.set_index(['DateTime'])

# %%
enso.head()
# Out:
#               YR  MON  TOTAL  ClimAdjust  ANOM
# DateTime
# 1950-01-01  1950    1  24.56       26.18 -1.62
# 1950-02-01  1950    2  25.07       26.39 -1.32
# 1950-03-01  1950    3  25.88       26.95 -1.07
# 1950-04-01  1950    4  26.29       27.39 -1.11
# 1950-05-01  1950    5  26.19       27.56 -1.37

# %% [markdown]
# ### Sunspot Number

# %%
#http://www.sidc.be/silso/monthlyssnplot
#http://www.sidc.be/silso/newdataset
columns= ['Year', 'Month', 'decimalYear', 'SNvalue' , 'SNerror', 'NBobservations', 'unspesified']
sunspots = read_csv('weather_data/SN_m_tot_V2.0.csv', sep=';', header=None, names=columns)

# %%
sunspots['DateTime'] = pd.to_datetime(sunspots.Year.map(str) + '-' + sunspots.Month.map(str))

# %%
sunspots = sunspots.set_index(['DateTime'])

# %%
sunspots.head()
# Out:
#             Year  Month  decimalYear  SNvalue  SNerror  NBobservations  \
# DateTime
# 1749-01-01  1749      1     1749.042     96.7     -1.0              -1
# 1749-02-01  1749      2     1749.123    104.3     -1.0              -1
# 1749-03-01  1749      3     1749.204    116.7     -1.0              -1
# 1749-04-01  1749      4     1749.288     92.8     -1.0              -1
# 1749-05-01  1749      5     1749.371    141.7     -1.0              -1
#
#             unspesified
# DateTime
# 1749-01-01            1
# 1749-02-01            1
# 1749-03-01            1
# 1749-04-01            1
# 1749-05-01            1

# %% [markdown]
# ### Range there is data of all the variables

# %%
#Choosing a range there is data of
anomalyrange = glb_formatted['1960-01-01' : '2018-12-01']
co2range = maunaloaFilled[['CO2filled']]['1960-01-01' : '2018-12-01']  #.CO2filled['1960-01-01' : '2018-12-01']
ensorange = enso[['ANOM']]['1960-01-01' : '2018-12-01']
spotsrange = sunspots[['SNvalue']]['1960-01-01' : '2018-12-01']

# %%
anomalyrange.to_csv('gridsearch_data/anomalyrange.csv')
co2range.to_csv('gridsearch_data/co2range.csv')
ensorange.to_csv('gridsearch_data/ensorange.csv')
spotsrange.to_csv('gridsearch_data/spotsrange.csv')

# %%
exogenous = pd.concat([co2range,ensorange,spotsrange], axis=1)

# %%
exogenous.tail()
# Out:
#             CO2filled  ANOM  SNvalue
# DateTime
# 2018-08-01     407.10  0.04      8.7
# 2018-09-01     405.59  0.39      3.3
# 2018-10-01     405.99  0.86      4.9
# 2018-11-01     408.12  0.86      5.9
# 2018-12-01     409.23  0.84      3.1

# %% [markdown]
# ## Plotting the data

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
anomalyrange.anomaly.plot(ax=ax)
plt.xlabel('Year')
plt.ylabel('Temperature Anomaly (*C)')
plt.title('Monthly NASA GISTEMP Global Means')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
co2range.CO2filled.plot(ax=ax)

plt.xlabel('Date')
plt.ylabel('C02 ppm')
plt.title('Monthly Hawaii Mauna Loa CO2 levels')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
ensorange.ANOM.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('Index')
plt.title('Monthly Oceanic Niño Index (ONI)')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
spotsrange.SNvalue.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('Solar spot observations')
plt.title('Monthly Sunspot observations')
plt.show()

# %% [markdown]
# ## Seasonal Decompositions

# %% [markdown]
# ### Temperature anomaly

# %%
res = sm.tsa.seasonal_decompose(anomalyrange.anomaly,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ### Hawaii CO2 ppm

# %%
res = sm.tsa.seasonal_decompose(co2range.CO2filled,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ### The Oceanic Niño Index (ONI)

# %%
res = sm.tsa.seasonal_decompose(ensorange.ANOM,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ### Sunspot observations

# %%
res = sm.tsa.seasonal_decompose(spotsrange.SNvalue,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ## Model Selection

# %%
#ARIMA model:(p,d,q)
#SARIMA model:(p,d,q)(P,D,Q,m)
#ARIMAX model:(p,d,q) + exog
#SARIMAX model:(p,d,q)(P,D,Q,m) +exog

#ARIMA(p,d,q)
#p is the number of autoregressive terms,
#d is the number of nonseasonal differences needed for stationarity, and
#q is the number of lagged forecast errors in the prediction equation.

#P: Seasonal autoregressive order.
#D: Seasonal difference order.
#Q: Seasonal moving average order.
#m: The number of time steps for a single seasonal period.

# %% [markdown]
# ### Checking Stationarity (Trend)

# %% [markdown]
# #### Temperature anomaly

# %% [markdown]
# Temperature anomaly lacks identifiable seasonal trend, but has a constant trend

# %%
res = sm.tsa.adfuller(anomalyrange.anomaly,regression='ct')
print('p-value:{}'.format(res[1]))
# data does not have a unit root and is stationary
# Out:
# p-value:1.6042922157092146e-09

# %%
res = sm.tsa.adfuller(anomalyrange.anomaly,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.5914744988244862

# %% [markdown]
# #### Hawaii CO2 ppm

# %% [markdown]
# CO2 concentration has both a seasonal and a constant trend

# %%
res = sm.tsa.adfuller(co2range.CO2filled,regression='ct')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.9885944880242227

# %%
res = sm.tsa.adfuller(co2range.CO2filled,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:1.0

# %% [markdown]
# #### The Oceanic Niño Index (ONI) and Sunspot observations

# %% [markdown]
# ONI and Sunspot observations have no trend

# %%
res = sm.tsa.adfuller(ensorange.ANOM,regression='ct')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:4.519555052443993e-08

# %%
res = sm.tsa.adfuller(ensorange.ANOM,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:2.5062854384841634e-09

# %%
res = sm.tsa.adfuller(spotsrange.SNvalue,regression='ct')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.0030167208232305537

# %%
res = sm.tsa.adfuller(spotsrange.SNvalue,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.0007375824522553518

# %% [markdown]
# ### Correlograms

# %% [markdown]
# #### Temperature anomaly

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(anomalyrange.anomaly.diff().dropna(), lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(anomalyrange.anomaly.diff().dropna(), lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# #### Hawaii CO2 ppm

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(co2range.CO2filled.diff().dropna(), lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(co2range.CO2filled.diff().dropna(), lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# #### The Oceanic Niño Index (ONI)

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(ensorange.ANOM, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(ensorange.ANOM, lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# #### Sunspot observations

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(spotsrange.SNvalue, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(spotsrange.SNvalue, lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# ### Train/Test-split

# %%
tr_start,tr_end = '1960-01-01','2012-12-01'
te_start,te_end = '2013-01-01','2018-12-01'

train_anomaly, test_anomaly = anomalyrange[tr_start : tr_end], anomalyrange[te_start:te_end]
train_co2, test_co2 = co2range[tr_start : tr_end], co2range[te_start: te_end]
train_enso, test_enso = ensorange[tr_start : tr_end], ensorange[te_start: te_end]
train_spots, test_spots = spotsrange[tr_start : tr_end], spotsrange[te_start: te_end]
train_exogenous, test_exogenous = exogenous[tr_start : tr_end], exogenous[te_start: te_end]

# %% [markdown]
# ### Gridsearch Hyperparameter selection

# %% [markdown]
# Alternative for the incode parameter selection, does not  support exogenous information. Was used to find parameter fo temperature anomaly and co2
#
# SARIMA-gridsearch code from:
# https://machinelearningmastery.com/how-to-grid-search-sarima-model-hyperparameters-for-time-series-forecasting-in-python/

# %% [markdown]
# format gridsearch.py filename.csv. You need to edit the sys.argv[1] parameter in to run these commands

# %%
# %run -i gridsearch.py anomalyrange.csv

# %%
#Best parameters for anomaly:
#[(2, 0, 2), (2, 0, 0, 0), 'c'] 0.16027624541442012
#[(2, 1, 2), (0, 0, 0, 0), 'c'] 0.16167729212744297
#[(1, 1, 1), (0, 0, 2, 0), 'c'] 0.16190864182572434

# %%
# %run -i gridsearch.py co2range.csv

# %%
# %run -i gridsearch.py ensorange.csv

# %%
# %run -i gridsearch.py spotsrange.csv

# %% [markdown]
# ## SARIMA model

# %%
sarima = sm.tsa.statespace.SARIMAX(train_anomaly,order=(2,1,2),trend='c',seasonal_order=(0,0,0,0),
                                 enforce_stationarity=False, enforce_invertibility=False,).fit()

sarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                anomaly   No. Observations:                  636
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 351.472
# Date:                Sat, 16 Feb 2019   AIC                           -690.943
# Time:                        21:37:15   BIC                           -664.212
# Sample:                    01-01-1960   HQIC                          -680.565
#                          - 12-01-2012
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0007      0.000      5.343      0.000       0.000       0.001
# ar.L1          0.2100      0.128      1.641      0.101      -0.041       0.461
# ar.L2          0.4008      0.074      5.408      0.000       0.256       0.546
# ma.L1         -0.7297      0.148     -4.932      0.000      -1.020      -0.440
# ma.L2         -0.2695      0.134     -2.017      0.044      -0.531      -0.008
# sigma2         0.0186      0.001     14.129      0.000       0.016       0.021
# ===================================================================================
# Ljung-Box (Q):                       52.28   Jarque-Bera (JB):                 2.39
# Prob(Q):                              0.09   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.09   Skew:                             0.12
# Prob(H) (two-sided):                  0.52   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred = sarima.predict(tr_end,te_end)[1:]
print('SARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred)))

pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred}).plot();plt.show()
# Out:
# SARIMA model MSE:0.048371172476643326

# %%
res = sarima.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# ### SARIMAX-model with CO2 as exogenous data

# %%
#p = d = q = range(0, 2)
p = range(0,3)
d = range(0,2)
q = range(0,3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 0) for x in list(itertools.product(p, d, q))]

# %%
warnings.filterwarnings("ignore") 

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_anomaly,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False,
                                            exog=train_co2
                                            )

            results = mod.fit()

            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))

        except:
            continue
# Out:
# SARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:152.53349744156617
# SARIMA(0, 0, 0)x(0, 0, 2, 12)12 - AIC:168.5271133882833
# SARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:-373.2577509057026
# SARIMA(0, 0, 0)x(0, 1, 2, 12)12 - AIC:-362.6030031096469
# SARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:-110.3306275718104
# SARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:-373.0339911063252
# SARIMA(0, 0, 0)x(1, 0, 2, 12)12 - AIC:-363.5348294307245
# SARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:-210.87787465466934
# SARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:-370.9172475511349
# SARIMA(0, 0, 0)x(1, 1, 2, 12)12 - AIC:-360.74863718801157
# SARIMA(0, 0, 0)x(2, 0, 0, 12)12 - AIC
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:-462.21529568074743
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:-562.2937985612617
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:-566.0242801595252
# SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:-685.9157983315818
# SARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:-670.8050235906958
# SARIMA(1, 1, 1)x(0, 0, 2, 12)12 - AIC:-654.1108823684845
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:-217.75964389407895
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:-607.8637437494215
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:-602.8047158110087
# SARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:-669.938474031563
# SARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:-670.8237689856436
# SARIMA(1, 1, 1)x(1, 0, 2, 12)12 - AIC:-653.3412159511537
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:-442.05761340652015
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:-615.1407792466805
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:-601.5296103969018
# SARIMA(1, 1, 1)x(2, 0, 0, 12)12 - AIC:-656.8280587518138
# SARIMA(1, 1, 1)x(2, 0, 1, 12)12 - AIC:-656.9553513177378
# SARIMA(1, 1, 1)x(2, 0, 2, 12)12 - AIC:-653.9501040400789
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:-493.65140577549874
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:-599.919209093669
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:-604.6002386805017
# SARIMA(1, 1, 2)x(0, 0, 0, 12)12 - AIC:-676.5497169193254
# SARIMA(1, 1, 2)x(0, 0, 1, 12)12 - AIC:-683.3268824077211
# SARIMA(1, 1, 2)x(0, 0, 2, 12)12 - AIC:-647.6209968275415
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:-216.37857030112764
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:-610.6033061037639
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:-597.2986752924735
# SARIMA(1, 1, 2)x(1, 0, 0, 12)12 - AIC:-663.6470376712767
# SARIMA(1, 1, 2)x(1, 0, 1, 12)12 - AIC:-676.6194507213127
# SARIMA(1, 1, 2)x(1, 0, 2, 12)12 - AIC:-646.9644596550777
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:-441.37106350740873
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:-608.9953995285134
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:-618.1683686060896
# SARIMA(1, 1, 2)x(2, 0, 0, 12)12 - AIC:-651.529823501088
# SARIMA(1, 1, 2)x(2, 0, 1, 12)12 - AIC:-651.3910528498527
# SARIMA(1, 1, 2)x(2, 0, 2, 12)12 - AIC:-644.8403303457028
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:-494.26353098552295
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:-594.372113689257
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:-598.0772279614619
# SARIMA(2, 0, 0)x(0, 0, 0, 12)12 - AIC:-639.1324648412083
# SARIMA(2, 0, 0)x(0, 0, 1, 12)12 - AIC:-642.5150494927502
# SARIMA(2, 0, 0)x(0, 0, 2, 12)12 - AIC:-632.9206648996619
# SARIMA(2, 0, 0)x(0, 1, 0, 12)12 - AIC:-263.55069616923106
# SARIMA(2, 0, 0)x(0, 1, 1, 12)12 - AIC:-638.0419916060974
# SARIMA(2, 0, 0)x(0, 1, 2, 12)12 - AIC:-629.9900520847262
# SARIMA(2, 0, 0)x(1, 0, 0, 12)12 - AIC:-640.9054743973008
# SARIMA(2, 0, 0)x(1, 0, 1, 12)12 - AIC:-637.8291543198503
# SARIMA(2, 0, 0)x(1, 0, 2, 12)12 - AIC:-637.9839820465368
# SARIMA(2, 0, 0)x(1, 1, 0, 12)12 - AIC:-478.93018264231057
# SARIMA(2, 0, 0)x(1, 1, 1, 12)12 - AIC:-641.7298190439869
# SARIMA(2, 0, 0)x(1, 1, 2, 12)12 - AIC:-629.0388662326422
# SARIMA(2, 0, 0)x(2, 0, 0, 12)12 - AIC:-634.4107768604621
# SARIMA(2, 0, 0)x(2, 0, 1, 12)12 - AIC:-637.9538914130386
# SARIMA(2, 0, 0)x(2, 0, 2, 12)12 - AIC:-636.0296062702135
# SARIMA(2, 0, 0)x(2, 1, 0, 12)12 - AIC:-523.8361028152984
# SARIMA(2, 0, 0)x(2, 1, 1, 12)12 - AIC:-627.8867257978395
# SARIMA(2, 0, 0)x(2, 1, 2, 12)12 - AIC:-629.1450596770388
# SARIMA(2, 0, 1)x(0, 0, 0, 12)12 - AIC:-668.5969429553427
# SARIMA(2, 0, 1)x(0, 0, 1, 12)12 - AIC:-664.3095629123279
# SARIMA(2, 0, 1)x(0, 0, 2, 12)12 - AIC:-655.3503257509858
# SARIMA(2, 0, 1)x(0, 1, 0, 12)12 - AIC:-261.9401898717309
# SARIMA(2, 0, 1)x(0, 1, 1, 12)12 - AIC:-634.704024729693
# SARIMA(2, 0, 1)x(0, 1, 2, 12)12 - AIC:-627.9499895212825
# SARIMA(2, 0, 1)x(1, 0, 0, 12)12 - AIC:-669.0633298870372
# SARIMA(2, 0, 1)x(1, 0, 1, 12)12 - AIC:-649.1894950219107
# SARIMA(2, 0, 1)x(1, 0, 2, 12)12 - AIC:-647.0330312268213
# SARIMA(2, 0, 1)x(1, 1, 0, 12)12 - AIC:-478.4135235130044
# SARIMA(2, 0, 1)x(1, 1, 1, 12)12 - AIC:-640.6425390059164
# SARIMA(2, 0, 1)x(1, 1, 2, 12)12 - AIC:-625.0638366344434
# SARIMA(2, 0, 1)x(2, 0, 0, 12)12 - AIC:-657.0499060824372
# SARIMA(2, 0, 1)x(2, 0, 1, 12)12 - AIC:-653.3370157989443
# SARIMA(2, 0, 1)x(2, 0, 2, 12)12 - AIC:-645.6131156217507
# SARIMA(2, 0, 1)x(2, 1, 0, 12)12 - AIC:-524.4246643331608
# SARIMA(2, 0, 1)x(2, 1, 1, 12)12 - AIC:-628.1550335618247
# SARIMA(2, 0, 1)x(2, 1, 2, 12)12 - AIC:-629.9242242901341
# SARIMA(2, 0, 2)x(0, 0, 0, 12)12 - AIC:-680.3373996442947
# SARIMA(2, 0, 2)x(0, 0, 1, 12)12 - AIC:-662.6224773108145
# SARIMA(2, 0, 2)x(0, 0, 2, 12)12 - AIC:-650.2925403007861
# SARIMA(2, 0, 2)x(0, 1, 0, 12)12 - AIC:-265.7198562395251
# SARIMA(2, 0, 2)x(0, 1, 1, 12)12 - AIC:-647.0292040755683
# SARIMA(2, 0, 2)x(0, 1, 2, 12)12 - AIC:-631.2587662096076
# SARIMA(2, 0, 2)x(1, 0, 0, 12)12 - AIC:-664.1988374271242
# SARIMA(2, 0, 2)x(1, 0, 1, 12)12 - AIC:-658.1665913016491
# SARIMA(2, 0, 2)x(1, 0, 2, 12)12 - AIC:-651.9399421719432
# SARIMA(2, 0, 2)x(1, 1, 0, 12)12 - AIC:-479.1288121531214
# SARIMA(2, 0, 2)x(1, 1, 1, 12)12 - AIC:-642.3160647735499
# SARIMA(2, 0, 2)x(1, 1, 2, 12)12 - AIC:-633.1647668257365
# SARIMA(2, 0, 2)x(2, 0, 0, 12)12 - AIC:-653.5607057995214
# SARIMA(2, 0, 2)x(2, 0, 1, 12)12 - AIC:-655.6939703433019
# SARIMA(2, 0, 2)x(2, 0, 2, 12)12 - AIC:-650.4819286030499
# SARIMA(2, 0, 2)x(2, 1, 0, 12)12 - AIC:-526.3655081934128
# SARIMA(2, 0, 2)x(2, 1, 1, 12)12 - AIC:-628.7916646287484
# SARIMA(2, 0, 2)x(2, 1, 2, 12)12 - AIC:-633.0057715217797
# SARIMA(2, 1, 0)x(0, 0, 0, 12)12 - AIC:-652.3613767641355
# SARIMA(2, 1, 0)x(0, 0, 1, 12)12 - AIC:-636.77544205566
# SARIMA(2, 1, 0)x(0, 0, 2, 12)12 - AIC:-624.7191319543529
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:-206.1586037443785
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:-591.2731739840951
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:-572.6246469195078
# SARIMA(2, 1, 0)x(1, 0, 0, 12)12 - AIC:-635.7468397860981
# SARIMA(2, 1, 0)x(1, 0, 1, 12)12 - AIC:-633.9077758441977
# SARIMA(2, 1, 0)x(1, 0, 2, 12)12 - AIC:-623.3981315610829
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:-426.1657583418431
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:-583.7433181497811
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:-576.7237307987493
# SARIMA(2, 1, 0)x(2, 0, 0, 12)12 - AIC:-624.3100376342436
# SARIMA(2, 1, 0)x(2, 0, 1, 12)12 - AIC:-623.7892478164215
# SARIMA(2, 1, 0)x(2, 0, 2, 12)12 - AIC:-622.3425009828039
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:-469.0128758506849
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:-573.8808770980681
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:-576.7869150843177
# SARIMA(2, 1, 1)x(0, 0, 0, 12)12 - AIC:-685.9247325896895
# SARIMA(2, 1, 1)x(0, 0, 1, 12)12 - AIC:-685.87695634091
# SARIMA(2, 1, 1)x(0, 0, 2, 12)12 - AIC:-670.8586295334553
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:-257.75481196676446
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:-626.0867515217836
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:-618.7211718113349
# SARIMA(2, 1, 1)x(1, 0, 0, 12)12 - AIC:-685.7715751719095
# SARIMA(2, 1, 1)x(1, 0, 1, 12)12 - AIC:-683.8932869946302
# SARIMA(2, 1, 1)x(1, 0, 2, 12)12 - AIC:-669.0606232947576
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:-471.75788754143815
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:-630.6199589882874
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:-617.1875500411579
# SARIMA(2, 1, 1)x(2, 0, 0, 12)12 - AIC:-672.8586765395794
# SARIMA(2, 1, 1)x(2, 0, 1, 12)12 - AIC:-672.0286420043623
# SARIMA(2, 1, 1)x(2, 0, 2, 12)12 - AIC:-669.7674209466708
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:-514.399114272705
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:-617.3533742146337
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:-620.4244795209165
# SARIMA(2, 1, 2)x(0, 0, 0, 12)12 - AIC:-690.5976064583851
# SARIMA(2, 1, 2)x(0, 0, 1, 12)12 - AIC:-683.3932510471348
# SARIMA(2, 1, 2)x(0, 0, 2, 12)12 - AIC:-669.1722981056325
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:-217.79912272316446
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:-624.6485355562456
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:-618.9426227644126
# SARIMA(2, 1, 2)x(1, 0, 0, 12)12 - AIC:-682.9606832363693
# SARIMA(2, 1, 2)x(1, 0, 1, 12)12 - AIC:-680.0803827772727
# SARIMA(2, 1, 2)x(1, 0, 2, 12)12 - AIC:-665.2134019398956
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:-449.6910861549518
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:-623.0346896539422
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:-613.5502519275603
# SARIMA(2, 1, 2)x(2, 0, 0, 12)12 - AIC:-670.173519353734
# SARIMA(2, 1, 2)x(2, 0, 1, 12)12 - AIC:-665.0349408018199
# SARIMA(2, 1, 2)x(2, 0, 2, 12)12 - AIC:-664.0482520181856
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:-498.5415652694153
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:-616.7068960768972
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:-612.927236023394

# %%
#Best parameters:
#SARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:-506.3849541853739
#SARIMA(0, 0, 2)x(0, 1, 1, 12)12 - AIC:-591.1336757476166
#SARIMA(0, 0, 2)x(1, 0, 1, 12)12 - AIC:-598.171093948506
#SARIMA(0, 0, 2)x(0, 1, 1, 12)12 - AIC:-591.1336757476166
#SARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:-682.6628888297496
#SARIMA(0, 1, 2)x(0, 0, 0, 12)12 - AIC:-678.1557308869063
#SARIMA(1, 0, 2)x(0, 0, 0, 12)12 - AIC:-680.2208349877351
#ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:-685.915798331581
#SARIMA(2, 0, 2)x(0, 0, 0, 12)12 - AIC:-680.3373996442947
#SARIMA(2, 1, 2)x(0, 0, 1, 12)12 - AIC:-683.3932510471348

# %%
#sarimax = sm.tsa.statespace.SARIMAX(train_anomaly,order=(2,1,2),trend='c', seasonal_order=(0,0,0,0),
#                                 enforce_stationarity=False, enforce_invertibility=False,exog=train_co2).fit()
sarimax = sm.tsa.statespace.SARIMAX(train_anomaly,order=(2,1,2),trend='c', seasonal_order=(0,0,0,0),
                                 enforce_stationarity=False, enforce_invertibility=False,exog=train_co2).fit()
sarimax.summary()
#-683
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                anomaly   No. Observations:                  636
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 350.856
# Date:                Sat, 16 Feb 2019   AIC                           -687.712
# Time:                        21:44:40   BIC                           -656.526
# Sample:                    01-01-1960   HQIC                          -675.604
#                          - 12-01-2012
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0005      0.000      1.843      0.065    -3.1e-05       0.001
# CO2filled      0.0064      0.004      1.617      0.106      -0.001       0.014
# ar.L1         -0.0257      0.109     -0.236      0.813      -0.239       0.188
# ar.L2          0.4646      0.054      8.577      0.000       0.358       0.571
# ma.L1         -0.4788      0.149     -3.205      0.001      -0.772      -0.186
# ma.L2         -0.5207      0.118     -4.401      0.000      -0.753      -0.289
# sigma2         0.0194      0.002      9.779      0.000       0.016       0.023
# ===================================================================================
# Ljung-Box (Q):                       59.50   Jarque-Bera (JB):                 1.93
# Prob(Q):                              0.02   Prob(JB):                         0.38
# Heteroskedasticity (H):               1.10   Skew:                             0.10
# Prob(H) (two-sided):                  0.47   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred = sarimax.predict(tr_end,te_end,exog=test_co2)[1:]
print('SARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred)))

pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred}).plot();plt.show()
# Out:
# SARIMA model MSE:0.04133845088968054

# %%
sarimax.plot_diagnostics(figsize=(15, 12))

# %% [markdown]
# ### SARIMAX-model with all Exogenous data

# %%
#p = d = q = range(0, 2)
p = range(0,3)
d = range(0,2)
q = range(0,3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 0) for x in list(itertools.product(p, d, q))]

# %%
warnings.filterwarnings("ignore")

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_anomaly,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False,
                                            exog=train_exogenous
                                            )

            results = mod.fit()

            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))

        except:
            continue
# Out:
# SARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:268.3668550771079
# SARIMA(0, 0, 0)x(0, 0, 2, 12)12 - AIC:189.25778003545557
# SARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:-419.2603293174624
# SARIMA(0, 0, 0)x(0, 1, 2, 12)12 - AIC:-403.70150657918464
# SARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:-123.87929046830206
# SARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:-362.0400589150881
# SARIMA(0, 0, 0)x(1, 0, 2, 12)12 - AIC:-310.70875556560543
# SARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:-246.59795534660736
# SARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:-386.7188802130672
# SARIMA(0, 0, 0)x(1, 1, 2, 12)12 - AIC:-401.8391599539588
# SARIMA(0, 0, 0)x(2, 0, 0, 12)12 - AIC:-254.29146086962396
# SARIMA(0, 0, 0)x(2, 0, 1, 12)12 - AIC:-327.30543547451293
# SARIMA(0, 0, 0)x(2, 0, 2, 12)12 - AIC:-384.4847005749366
# SARIMA(0, 0, 0)x(2, 1, 0, 12)12 - AIC:-302.129493348883
# SARIMA(0, 0, 0)x(2, 1, 1, 12)12 - AIC:-370.95627481282804
# SARIMA(0, 0, 0)x(2, 1, 2, 12)12 - AIC:-399.1235818766644
# SARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:22.918068350112804
# SARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:-86.42379885704585
# SARIMA(0, 0, 1)x(0, 0, 2, 12)12 - AIC:-183.28473863847054
# SARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:-155.1385804190455
# SARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:-538.1217201807212
# SARIMA(0, 0, 1)x(0, 1, 2, 12)12 - AIC:-520.1043864868343
# SARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:
# SARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:-664.7974915803768
# SARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:-664.7961465103147
# SARIMA(1, 0, 1)x(0, 0, 2, 12)12 - AIC:-652.4559525083265
# SARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:-258.71677784361896
# SARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:-639.953271417611
# SARIMA(1, 0, 1)x(0, 1, 2, 12)12 - AIC:-634.933771528733
# SARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:-654.9652977609614
# SARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:-654.4716310721449
# SARIMA(1, 0, 1)x(1, 0, 2, 12)12 - AIC:-654.0130294984735
# SARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:-479.9611659625928
# SARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:-647.5170328923646
# SARIMA(1, 0, 1)x(1, 1, 2, 12)12 - AIC:-628.705816116615
# SARIMA(1, 0, 1)x(2, 0, 0, 12)12 - AIC:-647.7967990043201
# SARIMA(1, 0, 1)x(2, 0, 1, 12)12 - AIC:-656.5605905459661
# SARIMA(1, 0, 1)x(2, 0, 2, 12)12 - AIC:-651.6984959191988
# SARIMA(1, 0, 1)x(2, 1, 0, 12)12 - AIC:-525.7430316486133
# SARIMA(1, 0, 1)x(2, 1, 1, 12)12 - AIC:-633.9117638804532
# SARIMA(1, 0, 1)x(2, 1, 2, 12)12 - AIC:-635.433319191765
# SARIMA(1, 0, 2)x(0, 0, 0, 12)12 - AIC:-679.0090371870006
# SARIMA(1, 0, 2)x(0, 0, 1, 12)12 - AIC:-662.5253154059669
# SARIMA(1, 0, 2)x(0, 0, 2, 12)12 - AIC:-651.2755507535873
# SARIMA(1, 0, 2)x(0, 1, 0, 12)12 - AIC:-265.9626207775699
# SARIMA(1, 0, 2)x(0, 1, 1, 12)12 - AIC:-646.3041440473866
# SARIMA(1, 0, 2)x(0, 1, 2, 12)12 - AIC:-632.2130920379844
# SARIMA(1, 0, 2)x(1, 0, 0, 12)12 - AIC:-639.6288629455141
# SARIMA(1, 0, 2)x(1, 0, 1, 12)12 - AIC:-653.6345936868736
# SARIMA(1, 0, 2)x(1, 0, 2, 12)12 - AIC:-650.7556336159035
# SARIMA(1, 0, 2)x(1, 1, 0, 12)12 - AIC:-477.04077027629296
# SARIMA(1, 0, 2)x(1, 1, 1, 12)12 - AIC:-632.3623688031564
# SARIMA(1, 0, 2)x(1, 1, 2, 12)12 - AIC:-632.4563512074253
# SARIMA(1, 0, 2)x(2, 0, 0, 12)12 - AIC:-642.9123410177021
# SARIMA(1, 0, 2)x(2, 0, 1, 12)12 - AIC:-655.8661931341701
# SARIMA(1, 0, 2)x(2, 0, 2, 12)12 - AIC:-648.9805319622399
# SARIMA(1, 0, 2)x(2, 1, 0, 12)12 - AIC:-519.9908114114016
# SARIMA(1, 0, 2)x(2, 1, 1, 12)12 - AIC:-603.4274369577885
# SARIMA(1, 0, 2)x(2, 1, 2, 12)12 - AIC:-632.9705514376766
# SARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:-622.0037554251356
# SARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:-624.3723455897697
# SARIMA(1, 1, 0)x(0, 0, 2, 12)12 - AIC:-613.0329296691806
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:-187.44588219098586
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:-562.6765721554444
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:-559.9378551995312
# SARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:-624.2859028484743
# SARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:-622.4441905310971
# SARIMA(1, 1, 0)x(1, 0, 2, 12)12 - AIC:-611.0003951132326
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:-409.6192102903325
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:-572.4851385925621
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:-555.8441144439224
# SARIMA(1, 1, 0)x(2, 0, 0, 12)12 - AIC:-614.4579635141483
# SARIMA(1, 1, 0)x(2, 0, 1, 12)12 - AIC:-612.8513596652577
# SARIMA(1, 1, 0)x(2, 0, 2, 12)12 - AIC:-610.2361678325101
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:-458.37632845033056
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:-559.0275303926126
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:-559.5745203552688
# SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:-685.2315859480459
# SARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:-668.5661408597749
# SARIMA(1, 1, 1)x(0, 0, 2, 12)12 - AIC:-654.6044320538824
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:-214.40004336943247
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:-597.2321124567662
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:-604.164360521719
# SARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:-670.1995826006763
# SARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:-665.1748207589237
# SARIMA(1, 1, 1)x(1, 0, 2, 12)12 - AIC:-651.1097565265696
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:-440.5138449999388
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:-607.7862999401331
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:-588.9631337739092
# SARIMA(1, 1, 1)x(2, 0, 0, 12)12 - AIC:-654.3196264333875
# SARIMA(1, 1, 1)x(2, 0, 1, 12)12 - AIC:-652.7795752938409
# SARIMA(1, 1, 1)x(2, 0, 2, 12)12 - AIC:-651.2240641230873
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:-491.28561641413216
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:-542.7838435136853
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:-595.7151899165965
# SARIMA(1, 1, 2)x(0, 0, 0, 12)12 - AIC:-674.0231932389912
# SARIMA(1, 1, 2)x(0, 0, 1, 12)12 - AIC:-663.6338503621304
# SARIMA(1, 1, 2)x(0, 0, 2, 12)12 - AIC:-644.1318492509552
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:-213.07165546616142
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:-609.450906981835
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:-596.1881991500268
# SARIMA(1, 1, 2)x(1, 0, 0, 12)12 - AIC:-661.8942582114607
# SARIMA(1, 1, 2)x(1, 0, 1, 12)12 - AIC:-656.6720413560649
# SARIMA(1, 1, 2)x(1, 0, 2, 12)12 - AIC:-642.2699936949464
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:-437.88663782472975
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:-606.2933810729528
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:-600.0391481948114
# SARIMA(1, 1, 2)x(2, 0, 0, 12)12 - AIC:-648.816512276326
# SARIMA(1, 1, 2)x(2, 0, 1, 12)12 - AIC:-647.2353262125447
# SARIMA(1, 1, 2)x(2, 0, 2, 12)12 - AIC:-640.9099269118963
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:-489.2287543102385
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:-590.2332916826009
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:-597.7098098627331
# SARIMA(2, 0, 0)x(0, 0, 0, 12)12 - AIC:-635.9907148388348
# SARIMA(2, 0, 0)x(0, 0, 1, 12)12 - AIC:-639.4318459349026
# SARIMA(2, 0, 0)x(0, 0, 2, 12)12 - AIC:-629.5891114750477
# SARIMA(2, 0, 0)x(0, 1, 0, 12)12 - AIC:-263.4528265410911
# SARIMA(2, 0, 0)x(0, 1, 1, 12)12 - AIC:-642.2343740732686
# SARIMA(2, 0, 0)x(0, 1, 2, 12)12 - AIC:-632.9618944796091
# SARIMA(2, 0, 0)x(1, 0, 0, 12)12 - AIC:-634.2627637317313
# SARIMA(2, 0, 0)x(1, 0, 1, 12)12 - AIC:-635.213150158081
# SARIMA(2, 0, 0)x(1, 0, 2, 12)12 - AIC:-634.3043340989503
# SARIMA(2, 0, 0)x(1, 1, 0, 12)12 - AIC:-478.65638413499664
# SARIMA(2, 0, 0)x(1, 1, 1, 12)12 - AIC:-640.3871585061215
# SARIMA(2, 0, 0)x(1, 1, 2, 12)12 - AIC:-630.4657387365181
# SARIMA(2, 0, 0)x(2, 0, 0, 12)12 - AIC:-630.6641325877997
# SARIMA(2, 0, 0)x(2, 0, 1, 12)12 - AIC:-634.517617429603
# SARIMA(2, 0, 0)x(2, 0, 2, 12)12 - AIC:-633.1584049156793
# SARIMA(2, 0, 0)x(2, 1, 0, 12)12 - AIC:-523.72892766771
# SARIMA(2, 0, 0)x(2, 1, 1, 12)12 - AIC:-626.9003891600221
# SARIMA(2, 0, 0)x(2, 1, 2, 12)12 - AIC:-632.6410228629511
# SARIMA(2, 0, 1)x(0, 0, 0, 12)12 - AIC:-650.6296794923685
# SARIMA(2, 0, 1)x(0, 0, 1, 12)12 - AIC:-651.8678346135746
# SARIMA(2, 0, 1)x(0, 0, 2, 12)12 - AIC:-641.5641860917507
# SARIMA(2, 0, 1)x(0, 1, 0, 12)12 - AIC:-261.65711036153766
# SARIMA(2, 0, 1)x(0, 1, 1, 12)12 - AIC:-638.5189948567291
# SARIMA(2, 0, 1)x(0, 1, 2, 12)12 - AIC:-631.1781906914696
# SARIMA(2, 0, 1)x(1, 0, 0, 12)12 - AIC:-649.9750750252413
# SARIMA(2, 0, 1)x(1, 0, 1, 12)12 - AIC:-645.77499251985
# SARIMA(2, 0, 1)x(1, 0, 2, 12)12 - AIC:-642.854784057795
# SARIMA(2, 0, 1)x(1, 1, 0, 12)12 - AIC:-477.03162299228046
# SARIMA(2, 0, 1)x(1, 1, 1, 12)12 - AIC:-642.4491010659954
# SARIMA(2, 0, 1)x(1, 1, 2, 12)12 - AIC:-626.5543208189981
# SARIMA(2, 0, 1)x(2, 0, 0, 12)12 - AIC:-641.8931367669287
# SARIMA(2, 0, 1)x(2, 0, 1, 12)12 - AIC:-645.6151425126651
# SARIMA(2, 0, 1)x(2, 0, 2, 12)12 - AIC:-642.6862022566928
# SARIMA(2, 0, 1)x(2, 1, 0, 12)12 - AIC:-522.3439201246506
# SARIMA(2, 0, 1)x(2, 1, 1, 12)12 - AIC:-605.1459780122583
# SARIMA(2, 0, 1)x(2, 1, 2, 12)12 - AIC:-629.9032484834459
# SARIMA(2, 0, 2)x(0, 0, 0, 12)12 - AIC:-676.3115360741862
# SARIMA(2, 0, 2)x(0, 0, 1, 12)12 - AIC:-659.9778601922694
# SARIMA(2, 0, 2)x(0, 0, 2, 12)12 - AIC:-647.0855877823004
# SARIMA(2, 0, 2)x(0, 1, 0, 12)12 - AIC:-265.470033510332
# SARIMA(2, 0, 2)x(0, 1, 1, 12)12 - AIC:-648.8950204474252
# SARIMA(2, 0, 2)x(0, 1, 2, 12)12 - AIC:-633.0434971156897
# SARIMA(2, 0, 2)x(1, 0, 0, 12)12 - AIC:-650.819982651642
# SARIMA(2, 0, 2)x(1, 0, 1, 12)12 - AIC:-655.064014967078
# SARIMA(2, 0, 2)x(1, 0, 2, 12)12 - AIC:-648.819072139165
# SARIMA(2, 0, 2)x(1, 1, 0, 12)12 - AIC:-476.73764300270705
# SARIMA(2, 0, 2)x(1, 1, 1, 12)12 - AIC:-633.2848644974695
# SARIMA(2, 0, 2)x(1, 1, 2, 12)12 - AIC:-634.8475295667729
# SARIMA(2, 0, 2)x(2, 0, 0, 12)12 - AIC:-645.808981388846
# SARIMA(2, 0, 2)x(2, 0, 1, 12)12 - AIC:-652.5794704677179
# SARIMA(2, 0, 2)x(2, 0, 2, 12)12 - AIC:-648.2191466518825
# SARIMA(2, 0, 2)x(2, 1, 0, 12)12 - AIC:-523.4262283339449
# SARIMA(2, 0, 2)x(2, 1, 1, 12)12 - AIC:-577.4786172800232
# SARIMA(2, 0, 2)x(2, 1, 2, 12)12 - AIC:-633.3112881240547
# SARIMA(2, 1, 0)x(0, 0, 0, 12)12 - AIC:-649.5934062084666
# SARIMA(2, 1, 0)x(0, 0, 1, 12)12 - AIC:-633.9614194117084
# SARIMA(2, 1, 0)x(0, 0, 2, 12)12 - AIC:-621.7025437290029
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:-202.7943546324294
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:-588.4267664906886
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:-569.6399986584668
# SARIMA(2, 1, 0)x(1, 0, 0, 12)12 - AIC:-632.9416292829133
# SARIMA(2, 1, 0)x(1, 0, 1, 12)12 - AIC:-630.8875055969961
# SARIMA(2, 1, 0)x(1, 0, 2, 12)12 - AIC:-619.6727894498517
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:-422.86473511310953
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:-580.868587614986
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:-573.5699257476911
# SARIMA(2, 1, 0)x(2, 0, 0, 12)12 - AIC:-621.3533536068164
# SARIMA(2, 1, 0)x(2, 0, 1, 12)12 - AIC:-619.6462693076126
# SARIMA(2, 1, 0)x(2, 0, 2, 12)12 - AIC:-616.7250073733394
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:-465.34919522258804
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:-570.4786829983295
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:-572.8162598100902
# SARIMA(2, 1, 1)x(0, 0, 0, 12)12 - AIC:-676.7365483593665
# SARIMA(2, 1, 1)x(0, 0, 1, 12)12 - AIC:-674.8299276784717
# SARIMA(2, 1, 1)x(0, 0, 2, 12)12 - AIC:-658.552528270104
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:-257.22279297587994
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:-628.6868578952808
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:-621.2702298109649
# SARIMA(2, 1, 1)x(1, 0, 0, 12)12 - AIC:-674.3897100356273
# SARIMA(2, 1, 1)x(1, 0, 1, 12)12 - AIC:-672.4287249175377
# SARIMA(2, 1, 1)x(1, 0, 2, 12)12 - AIC:-655.9929454363637
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:-471.8739164859113
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:-626.9855116970062
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:-618.5816755453721
# SARIMA(2, 1, 1)x(2, 0, 0, 12)12 - AIC:-660.5395878566071
# SARIMA(2, 1, 1)x(2, 0, 1, 12)12 - AIC:-657.8216513531255
# SARIMA(2, 1, 1)x(2, 0, 2, 12)12 - AIC:-657.2060210472416
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:-514.5153589807915
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:-565.7780103277125
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:-620.6778400662386
# SARIMA(2, 1, 2)x(0, 0, 0, 12)12 - AIC:-688.2766397735196
# SARIMA(2, 1, 2)x(0, 0, 1, 12)12 - AIC:-680.2113252392235
# SARIMA(2, 1, 2)x(0, 0, 2, 12)12 - AIC:-665.4579465762481
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:-216.11423610482086
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:-616.6116371931199
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:-610.5741774348713
# SARIMA(2, 1, 2)x(1, 0, 0, 12)12 - AIC:-681.5093982299088
# SARIMA(2, 1, 2)x(1, 0, 1, 12)12 - AIC:-677.3349313455151
# SARIMA(2, 1, 2)x(1, 0, 2, 12)12 - AIC:-661.8237325958971
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:-462.1115807718585
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:-619.5467705595205
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:-617.3427232351022
# SARIMA(2, 1, 2)x(2, 0, 0, 12)12 - AIC:-664.6224611695303
# SARIMA(2, 1, 2)x(2, 0, 1, 12)12 - AIC:-663.6333854803171
# SARIMA(2, 1, 2)x(2, 0, 2, 12)12 - AIC:-659.8449918881635
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:-496.0962210314692
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:-559.6741910905944
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:-610.4092867073284

# %%
#Best parameters:
#SARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:-681.4464470288331
#SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:-685.2315859480459
#SARIMA(2, 1, 2)x(0, 0, 0, 12)12 - AIC:-688.2766397735196

# %%
#https://www.windows2universe.org/sun/activity/sunspot_cycle.html&edu=mid has an eleven year cycle
sarimax = sm.tsa.statespace.SARIMAX(train_anomaly,order=(0,1,1),trend='c',seasonal_order=(0,0,0,0),
                                 enforce_stationarity=False, enforce_invertibility=False,exog=train_exogenous).fit()
sarimax.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                anomaly   No. Observations:                  636
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 345.794
# Date:                Sat, 16 Feb 2019   AIC                           -679.587
# Time:                        22:09:12   BIC                           -652.856
# Sample:                    01-01-1960   HQIC                          -669.209
#                          - 12-01-2012
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0009      0.002      0.363      0.717      -0.004       0.006
# CO2filled      0.0055      0.003      1.827      0.068      -0.000       0.011
# ANOM           0.0215      0.015      1.479      0.139      -0.007       0.050
# SNvalue     7.343e-05      0.000      0.295      0.768      -0.000       0.001
# ma.L1         -0.5905      0.033    -17.772      0.000      -0.656      -0.525
# sigma2         0.0196      0.001     17.669      0.000       0.017       0.022
# ===================================================================================
# Ljung-Box (Q):                       62.01   Jarque-Bera (JB):                 0.76
# Prob(Q):                              0.01   Prob(JB):                         0.68
# Heteroskedasticity (H):               1.18   Skew:                             0.06
# Prob(H) (two-sided):                  0.22   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Predictable adding noisy data did not improve the model over co2

# %%
pred = sarimax.predict(tr_end,te_end,exog=test_exogenous)[1:]
print('SARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred)))

pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred}).plot();plt.show()
# Out:
# SARIMA model MSE:0.05509657794128058

# %%
sarimax.plot_diagnostics(figsize=(15, 12))

# %% [markdown]
# # Final predictions

# %% [markdown]
# ### SARIMAX-prediction with CO2

# %% [markdown]
# #### Generate future prediction of co2 concentration

# %%
sarima = sm.tsa.statespace.SARIMAX(co2range,order=(2,1,2),trend='ct', seasonal_order=(0,1,0,12),
                                 enforce_stationarity=False, enforce_invertibility=False).fit()

sarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                          CO2filled   No. Observations:                  708
# Model:             SARIMAX(2, 1, 2)x(0, 1, 0, 12)   Log Likelihood                -351.311
# Date:                            Sat, 16 Feb 2019   AIC                            716.622
# Time:                                    22:23:36   BIC                            748.560
# Sample:                                01-01-1960   HQIC                           728.962
#                                      - 12-01-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0079      0.019      0.408      0.683      -0.030       0.046
# drift      -1.066e-05    4.2e-05     -0.254      0.800   -9.29e-05    7.16e-05
# ar.L1         -0.2520      0.742     -0.339      0.734      -1.707       1.203
# ar.L2          0.1576      0.116      1.357      0.175      -0.070       0.385
# ma.L1         -0.1369      0.743     -0.184      0.854      -1.594       1.320
# ma.L2         -0.2913      0.383     -0.760      0.448      -1.043       0.460
# sigma2         0.1619      0.009     18.804      0.000       0.145       0.179
# ===================================================================================
# Ljung-Box (Q):                      204.88   Jarque-Bera (JB):                 1.17
# Prob(Q):                              0.00   Prob(JB):                         0.56
# Heteroskedasticity (H):               1.52   Skew:                             0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction   = sarima.get_forecast(steps=374)

# %%
prediction.predicted_mean.tail()
# Out:
# 2049-10-01    477.230409
# 2049-11-01    479.311914
# 2049-12-01    480.372945
# 2050-01-01    481.647965
# 2050-02-01    481.853727
# Freq: MS, dtype: float64

# %%
pred_ci = prediction.conf_int()

# %%
ax = co2range.CO2filled.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')

plt.legend()
plt.show()

# %% [markdown]
# #### Prediction with co2 as exogenous variable

# %%
mod = sm.tsa.statespace.SARIMAX(anomalyrange.anomaly,order=(2,1,2),trend='c', seasonal_order=(0,0,0,0),
                                 enforce_stationarity=False, enforce_invertibility=False,exog=co2range.values)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                anomaly   No. Observations:                  708
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 379.793
# Date:                Sat, 16 Feb 2019   AIC                           -745.587
# Time:                        22:43:04   BIC                           -713.650
# Sample:                    01-01-1960   HQIC                          -733.248
#                          - 12-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0004      0.000      2.316      0.021    6.04e-05       0.001
# x1             0.0057      0.003      1.899      0.058      -0.000       0.012
# ar.L1          0.3613      0.174      2.077      0.038       0.020       0.702
# ar.L2          0.2496      0.098      2.549      0.011       0.058       0.442
# ma.L1         -0.9454      0.178     -5.315      0.000      -1.294      -0.597
# ma.L2         -0.0552      0.180     -0.307      0.759      -0.408       0.297
# sigma2         0.0206      0.001     14.323      0.000       0.018       0.023
# ===================================================================================
# Ljung-Box (Q):                       49.06   Jarque-Bera (JB):                 1.71
# Prob(Q):                              0.15   Prob(JB):                         0.42
# Heteroskedasticity (H):               1.18   Skew:                             0.11
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction = res.get_forecast(steps=374, exog=prediction.predicted_mean.reshape(374,1))

# %%
prediction.predicted_mean.tail()
# Out:
# 2049-10-01    1.840690
# 2049-11-01    1.853486
# 2049-12-01    1.860503
# 2050-01-01    1.868732
# 2050-02-01    1.870906
# Freq: MS, dtype: float64

# %%
pred_ci = prediction.conf_int()

# %%
ax = anomalyrange.anomaly.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_title('Temperature Anomaly Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature Anomaly (*C)')

plt.legend()
plt.show()

# %% [markdown]
# ## SARIMA-prediction

# %%
mod = sm.tsa.statespace.SARIMAX(anomalyrange.anomaly,order=(2,1,2),trend='c', seasonal_order=(0,0,0,0),
                                 enforce_stationarity=False, enforce_invertibility=False)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                anomaly   No. Observations:                  708
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 378.278
# Date:                Sat, 16 Feb 2019   AIC                           -744.555
# Time:                        23:01:38   BIC                           -717.180
# Sample:                    01-01-1960   HQIC                          -733.979
#                          - 12-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0007      0.000      5.380      0.000       0.000       0.001
# ar.L1          0.1886      0.119      1.591      0.112      -0.044       0.421
# ar.L2          0.4115      0.067      6.112      0.000       0.280       0.544
# ma.L1         -0.7337      0.138     -5.309      0.000      -1.004      -0.463
# ma.L2         -0.2667      0.132     -2.016      0.044      -0.526      -0.007
# sigma2         0.0196      0.002      9.797      0.000       0.016       0.024
# ===================================================================================
# Ljung-Box (Q):                       50.77   Jarque-Bera (JB):                 2.41
# Prob(Q):                              0.12   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.15   Skew:                             0.13
# Prob(H) (two-sided):                  0.27   Kurtosis:                         3.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction = res.get_forecast(steps=374)

# %%
prediction.predicted_mean.tail()
# Out:
# 2049-10-01    1.686525
# 2049-11-01    1.688279
# 2049-12-01    1.690032
# 2050-01-01    1.691785
# 2050-02-01    1.693538
# Freq: MS, dtype: float64

# %%
pred_ci = prediction.conf_int()

# %%
ax = anomalyrange.anomaly.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_title('Temperature Anomaly Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature Anomaly (*C)')

plt.legend()
plt.show()
