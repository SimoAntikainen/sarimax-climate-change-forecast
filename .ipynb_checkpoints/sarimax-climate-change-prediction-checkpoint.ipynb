# %%
from pandas import read_csv
from pandas import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
from statsmodels.tsa.arima_model import ARIMA
#from statsmodels.tsa.sarimax_model import SARIMAX
import statsmodels.api as sm
import math
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\Simo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#https://www.kaggle.com/poiupoiu/how-to-use-sarimax

# %%
columns= ['Year', 'Month', 'Excel', 'Date', 'CO2', 'sesonalCO2', 'FIT','sesonalFIT', 'CO2filled', 'seasonalCO2filled']

maunaloa = read_csv('maunaloa.csv', skiprows=57, header=None, names=columns)

# %%
maunaloa['DateTime']  = pd.to_datetime(maunaloa.Year.map(str) + '-' + maunaloa.Month.map(str))
maunaloa = maunaloa.set_index(['DateTime'])

# %%
maunaloa.head()

# %%
maunaloaFilled = maunaloa[['CO2filled', 'seasonalCO2filled']]
maunaloaFilled.replace(to_replace=[-99.99], value=np.nan, inplace=True)

# %%
columns= ['Year', 'Month', 'Excel', 'Date', 'CO2', 'sesonalCO2', 'FIT','sesonalFIT', 'CO2filled', 'seasonalCO2filled']
maunaloa = read_csv('maunaloa.csv', skiprows=57, header=None, names=columns)

maunaloa['DateTime']  = pd.to_datetime(maunaloa.Year.map(str) + '-' + maunaloa.Month.map(str))
maunaloa = maunaloa.set_index(['DateTime'])

maunaloa.head()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
pt_CO2fit = maunaloaFilled.CO2filled.plot(ax=ax)
pt_CO2 = maunaloaFilled.seasonalCO2filled.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('C02 ppm')
plt.title('Hawaii CO2 levels')
plt.show()

# %%
glb = read_csv('GLB.Ts.csv', skiprows=1)

# %%
glb.iloc[:,0:13].head()

# %%
col_names =  ['DateTime', 'anomaly']
glb_formatted = pd.DataFrame(columns = col_names)

# %%
glb_formatted

# %%
at = 0
for index, row in glb.iterrows():
    #print(row['c1'], row['c2'])
    i = 0
    months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    for r in row[1:13]:
        #print(r)
        date = pd.to_datetime(str(row['Year']) + '-' + months[i])
        #print(date)
        value = r
        glb_formatted.loc[at] = [date, value]
        at = at + 1
        i = i + 1
    i= 1

# %%
glb_formatted = glb_formatted.set_index(['DateTime'])

# %%
glb_formatted.tail()

# %%
#https://data.giss.nasa.gov/gistemp/
#Global-mean monthly, seasonal, and annual means
glb = read_csv('GLB.Ts.csv', skiprows=1)
glb.head()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
anomaly = glb_formatted.anomaly.plot(ax=ax)
plt.xlabel('Year')
plt.ylabel('Temperature Anomaly (*C)')
plt.title('NASA GISTEMP Global Means')
plt.show()

# %%
#https://www.co2.earth/historical-co2-datasets
co2historical = read_csv('co2historical.csv')

# %%
co2historical = co2historical.set_index(['datetime'])

# %%
co2historical.tail

# %%
co2historical.iloc[21599]

# %%
#co2historical['03-Jan-1880 00:00:00':'15-Dec-2014 00:00:00']
hist_splice = co2historical['15-Jan-1880 00:00:00':'15-Dec-2014 00:00:00']

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
data_mean_global = hist_splice.data_mean_global.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('C02 ppm')
plt.title('Historical CO2 levels')
plt.show()

# %%
len(hist_splice)

# %%
len(glb_formatted)

# %%
model = ARIMA(hist_splice.data_mean_global, order=(5,1,0))
model_fit = model.fit(disp=0)

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()

# %%
predictions_time = pd.DataFrame(data=predictions,
                  index=test.index)

# %%
plt.figure(figsize=(20,10))
plt.locator_params(nbins=6)

#plt.plot(test)
#plt.plot(predictions, color='red')
plt.plot(test.index, test.values)
plt.plot(predictions_time.index, predictions_time[[0]])


plt.show()

# %%
arr = pd.DataFrame(dict(s1 = test, s2 = predictions)).reset_index()
arr.head()

# %%
from sklearn.metrics import mean_squared_error

#https://stackoverflow.com/questions/6682784/reducing-number-of-plot-ticks

X = maunaloaFilled.CO2filled.dropna()#hist_splice.data_mean_global
size = int(len(X) * 0.95)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot

#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.locator_params(nbins=6)
#pyplot.figure(figsize=(20,10))
#pyplot.show()

# %% [markdown]
# # Reading and preprocessing the data

# %% [markdown]
# #### NASA GISTEMP Global Means

# %%
glb = read_csv('weather_data/GLB.Ts.csv', skiprows=1)
glb.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.76 -0.35 -0.42 -0.60 -0.30 -0.42 -0.41  0.13 -0.44 -0.60 -0.45
# 1  1881 -0.74 -0.56 -0.31 -0.21  0.02 -1.05 -0.47 -0.19 -0.29 -0.42 -0.50
# 2  1882  0.18 -0.05 -0.03 -0.54 -0.33 -0.97 -0.66 -0.06 -0.02 -0.25 -0.34
# 3  1883 -0.62 -0.89 -0.40 -0.26 -0.30  0.50  0.04 -0.10 -0.40 -0.51 -0.63
# 4  1884 -0.56 -0.30 -0.36 -0.90 -1.16 -0.79 -0.81  0.19 -0.33 -0.73 -0.78
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.47 -0.43   ***   *** -0.44 -0.24 -0.50
# 1 -0.09 -0.40  -.43  -.59 -0.16 -0.57 -0.40
# 2 -0.62 -0.31  -.26   .01 -0.30 -0.56 -0.20
# 3 -0.33 -0.32  -.35  -.71 -0.32  0.15 -0.51
# 4 -0.97 -0.63  -.57  -.40 -0.81 -0.47 -0.61

# %%
#https://data.giss.nasa.gov/gistemp/
def preprocess_temp_anomaly(anomaly):
    
    col_names =  ['DateTime', 'anomaly']
    glb_formatted = pd.DataFrame(columns = col_names)
    
    at = 0
    for index, row in glb.iterrows():
        i = 0
        months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
        for r in row[1:13]:
            date = pd.to_datetime(str(row['Year']) + '-' + months[i])
            value = r
            glb_formatted.loc[at] = [date, value]
            at = at + 1
            i = i + 1
        i= 1
    
    glb_formatted = glb_formatted.set_index(['DateTime'])
    
    return glb_formatted


glb_formatted = preprocess_temp_anomaly(glb)
glb_formatted.head()
# Out:
#             anomaly
# DateTime
# 1880-01-01    -0.76
# 1880-02-01    -0.35
# 1880-03-01    -0.42
# 1880-04-01    -0.60
# 1880-05-01    -0.30

# %% [markdown]
# #### Monthly mean carbon dioxide at Mauna Loa Observatory, Hawaii

# %%
columns= ['Year', 'Month', 'Excel', 'Date', 'CO2', 'sesonalCO2', 'FIT','sesonalFIT', 'CO2filled', 'seasonalCO2filled']

maunaloa = read_csv('weather_data/maunaloa.csv', skiprows=57, header=None, names=columns)

maunaloa['DateTime']  = pd.to_datetime(maunaloa.Year.map(str) + '-' + maunaloa.Month.map(str))
maunaloa = maunaloa.set_index(['DateTime'])

maunaloa.head()
# Out:
#             Year  Month  Excel       Date     CO2  sesonalCO2     FIT  \
# DateTime
# 1958-01-01  1958      1  21200  1958.0411  -99.99      -99.99  -99.99
# 1958-02-01  1958      2  21231  1958.1260  -99.99      -99.99  -99.99
# 1958-03-01  1958      3  21259  1958.2027  315.70      314.43  316.19
# 1958-04-01  1958      4  21290  1958.2877  317.45      315.15  317.30
# 1958-05-01  1958      5  21320  1958.3699  317.51      314.72  317.85
#
#             sesonalFIT  CO2filled  seasonalCO2filled
# DateTime
# 1958-01-01      -99.99     -99.99             -99.99
# 1958-02-01      -99.99     -99.99             -99.99
# 1958-03-01      314.90     315.70             314.43
# 1958-04-01      314.98     317.45             315.15
# 1958-05-01      315.06     317.51             314.72

# %%
maunaloaFilled = maunaloa[['CO2filled', 'seasonalCO2filled']].copy()
maunaloaFilled.replace(to_replace=[-99.99], value=np.nan, inplace=True)

# %% [markdown]
# ### The Oceanic Niño Index (ONI)

# %%
#https://data.humdata.org/dataset/monthly-oceanic-nino-index-oni

# %%
enso = read_csv('weather_data/Monthly Oceanic Nino Index (ONI) - Long.csv')

# %%
enso['DateTime'] = pd.to_datetime(enso['PeriodNum'])
enso = enso.set_index(['DateTime'])

# %%
enso.head()
# Out:
#             Year MonthTxt  MonthNum PeriodTxt PeriodNum  Value
# DateTime
# 1950-01-01  1950      DJF         1  1950-DJF   1950-01   -1.4
# 1950-02-01  1950      JFM         2  1950-JFM   1950-02   -1.2
# 1950-03-01  1950      FMA         3  1950-FMA   1950-03   -1.1
# 1950-04-01  1950      MAM         4  1950-MAM   1950-04   -1.2
# 1950-05-01  1950      AMJ         5  1950-AMJ   1950-05   -1.1

# %% [markdown]
# ### Sunspot Number

# %%
#http://www.sidc.be/silso/monthlyssnplot
#http://www.sidc.be/silso/newdataset
columns= ['Year', 'Month', 'decimalYear', 'SNvalue' , 'SNerror', 'NBobservations', 'unspesified']
sunspots = read_csv('weather_data/SN_m_tot_V2.0.csv', sep=';', header=None, names=columns)

# %%
sunspots['DateTime'] = pd.to_datetime(sunspots.Year.map(str) + '-' + sunspots.Month.map(str))

# %%
sunspots = sunspots.set_index(['DateTime'])

# %%
sunspots.head()
# Out:
#             Year  Month  decimalYear  SNvalue  SNerror  NBobservations  \
# DateTime
# 1749-01-01  1749      1     1749.042     96.7     -1.0              -1
# 1749-02-01  1749      2     1749.123    104.3     -1.0              -1
# 1749-03-01  1749      3     1749.204    116.7     -1.0              -1
# 1749-04-01  1749      4     1749.288     92.8     -1.0              -1
# 1749-05-01  1749      5     1749.371    141.7     -1.0              -1
#
#             unspesified
# DateTime
# 1749-01-01            1
# 1749-02-01            1
# 1749-03-01            1
# 1749-04-01            1
# 1749-05-01            1

# %% [markdown]
# ### Range there is data of all the variables

# %%
#Choosing a range there is data of
anomalyrange = glb_formatted['1960-01-01' : '2018-12-01']
co2range = maunaloaFilled[['CO2filled']]['1960-01-01' : '2018-12-01']  #.CO2filled['1960-01-01' : '2018-12-01']
ensorange = enso[['Value']]['1960-01-01' : '2018-12-01']
spotsrange = sunspots[['SNvalue']]['1960-01-01' : '2018-12-01']

# %% [markdown]
# ## Plotting the data

# %%
co2range.head()
# Out:
#             CO2filled
# DateTime
# 1960-01-01     316.43
# 1960-02-01     316.98
# 1960-03-01     317.58
# 1960-04-01     319.03
# 1960-05-01     320.04

# %%
anomalyrange.head()
# Out:
#             anomaly
# DateTime
# 1960-01-01     0.07
# 1960-02-01     0.26
# 1960-03-01    -0.47
# 1960-04-01    -0.21
# 1960-05-01    -0.15

# %%
ensorange.head()
# Out:
#             Value
# DateTime
# 1960-01-01   -0.1
# 1960-02-01   -0.2
# 1960-03-01   -0.1
# 1960-04-01    0.0
# 1960-05-01   -0.1

# %%
spotsrange.loc['1982-11-01'] #.tail()
# Out:
# NBobservations    244
# Name: 1982-11-01 00:00:00, dtype: int64

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
anomalyrange.anomaly.plot(ax=ax)
plt.xlabel('Year')
plt.ylabel('Temperature Anomaly (*C)')
plt.title('NASA GISTEMP Global Means')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
co2range.CO2filled.plot(ax=ax)

plt.xlabel('Date')
plt.ylabel('C02 ppm')
plt.title('Hawaii Mauna Loa CO2 levels')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
sunspots.SNvalue.plot(ax=ax)
#pt_CO2 = maunaloaFilled.seasonalCO2filled.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('Index')
plt.title('The Oceanic Niño Index (ONI)')
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12,7))
spotsrange.SNvalue.plot(ax=ax)
#pt_CO2 = maunaloaFilled.seasonalCO2filled.plot(ax=ax)
plt.xlabel('Date')
plt.ylabel('Solar spot observations')
plt.title('Monthly Solar spot observations')
plt.show()

# %% [markdown]
# ## Seasonal Decomposition

# %% [markdown]
# #### Temperature anomaly

# %%
res = sm.tsa.seasonal_decompose(co2range.CO2filled,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# #### Hawaii CO2 ppm

# %%
res = sm.tsa.seasonal_decompose(anomalyrange.anomaly,freq=12)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ## Model Selection

# %%
#ARIMA model:(p,d,q)
#SARIMA model:(p,d,q)(P,D,Q,m)
#ARIMAX model:(p,d,q) + exog
#SARIMAX model:(p,d,q)(P,D,Q,m) +exog

#ARIMA(p,d,q)
#p is the number of autoregressive terms,
#d is the number of nonseasonal differences needed for stationarity, and
#q is the number of lagged forecast errors in the prediction equation.

#P: Seasonal autoregressive order.
#D: Seasonal difference order.
#Q: Seasonal moving average order.
#m: The number of time steps for a single seasonal period.

# %% [markdown]
# ### Checking Stationarity (Trend)

# %% [markdown]
# #### Temperature anomaly

# %%
res = sm.tsa.adfuller(anomalyrange.anomaly,regression='ct')
print('p-value:{}'.format(res[1]))
# data does not have a unit root and is stationary
# Out:
# p-value:1.6042922157092146e-09

# %%
res = sm.tsa.adfuller(anomalyrange.anomaly,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.5914744988244862

# %% [markdown]
# #### Hawaii CO2 ppm

# %%
res = sm.tsa.adfuller(co2range.CO2filled,regression='ct')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:0.9885944880242227

# %%
res = sm.tsa.adfuller(co2range.CO2filled,regression='c')
print('p-value:{}'.format(res[1]))
# data has a unit root and is non-stationary.
# Out:
# p-value:1.0

# %% [markdown]
# ### Correlograms

# %%
#diff is for unit root processes
#x.diff().dropna() dropna because the first element is nan.

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(anomalyrange.anomaly.diff().dropna(), lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(anomalyrange.anomaly.diff().dropna(), lags=50, ax=ax[1])
plt.show()

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(co2range.CO2filled.diff().dropna(), lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(co2range.CO2filled.diff().dropna(), lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# ### Selecting ARMA(p,q)-parameters

# %%
#https://github.com/statsmodels/statsmodels/issues/4727
#You need to give raw values 
resDiff = sm.tsa.arma_order_select_ic(anomalyrange.anomaly, max_ar=12, max_ma=12)
print('ARMA(p,q) =',resDiff['aic_min_order'],'is the best.')

# %%
#print ('AIC-order: {}' .format(resDiff.aic_min_order))
print ('BIC-order: {}' .format(resDiff.bic_min_order))
#print ('HQIC-order: {}' .format(resDiff.hqic_min_order))

# %%
resDiff

# %% [markdown]
# ### ARIMA-model

# %%
#ARIMA(p,d,q)
#p is the number of autoregressive terms,
#d is the number of nonseasonal differences needed for stationarity, and
#q is the number of lagged forecast errors in the prediction equation.

# %%
tr_start,tr_end = '1960-01-01','2010-12-01'
te_start,te_end = '2011-01-01','2018-12-01'

train_anomaly, test_anomaly = anomalyrange[tr_start : tr_end], anomalyrange[te_start:te_end]
train_co2, test_co2 = co2range[tr_start : tr_end], co2range[te_start: te_end]

# %%
len(test_anomaly)
# Out:
# 96

# %%
#arima = sm.tsa.statespace.SARIMAX(train_anomaly,order=(1,1,2),freq='M',seasonal_order=(0,0,0,0),
#                                 enforce_stationarity=False, enforce_invertibility=False,).fit()
arima = ARIMA(train_anomaly, order=(1,1,2)).fit(disp=0)


#arima.summary()
# Out:
# C:\Users\Simo\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\Simo\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):

# %%
res = arima.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()
# Out:
# C:\Users\Simo\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
pred = arima.predict(tr_end,te_end) #[1:]
#print('ARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred.values)))

# %%
pred
# Out:
# 2010-12-01   -0.071157
# 2011-01-01    0.156462
# 2011-02-01   -0.018246
# 2011-03-01    0.019364
# 2011-04-01   -0.015162
# 2011-05-01    0.016533
# 2011-06-01   -0.012563
# 2011-07-01    0.014147
# 2011-08-01   -0.010373
# 2011-09-01    0.012136
# 2011-10-01   -0.008527
# 2011-11-01    0.010442
# 2011-12-01   -0.006971
# 2012-01-01    0.009014
# 2012-02-01   -0.005661
# 2012-03-01    0.007811
# 2012-04-01   -0.004556
# 2012-05-01    0.006797
# 2012-06-01   -0.003625
# 2012-07-01    0.005942
# 2012-08-01   -0.002841
# 2012-09-01    0.005222
# 2012-10-01   -0.002179
# 2012-11-01    0.004615
# 2012-12-01   -0.001622
# 2013-01-01    0.004104
# 2013-02-01   -0.001153
# 2013-03-01    0.003673
# 2013-04-01   -0.000757
# 2013-05-01    0.003309
#                 ...
# 2016-07-01    0.001438
# 2016-08-01    0.001294
# 2016-09-01    0.001427
# 2016-10-01    0.001305
# 2016-11-01    0.001417
# 2016-12-01    0.001314
# 2017-01-01    0.001408
# 2017-02-01    0.001322
# 2017-03-01    0.001401
# 2017-04-01    0.001328
# 2017-05-01    0.001395
# 2017-06-01    0.001334
# 2017-07-01    0.001390
# 2017-08-01    0.001338
# 2017-09-01    0.001386
# 2017-10-01    0.001342
# 2017-11-01    0.001382
# 2017-12-01    0.001346
# 2018-01-01    0.001379
# 2018-02-01    0.001348
# 2018-03-01    0.001377
# 2018-04-01    0.001351
# 2018-05-01    0.001375
# 2018-06-01    0.001353
# 2018-07-01    0.001373
# 2018-08-01    0.001354
# 2018-09-01    0.001371
# 2018-10-01    0.001356
# 2018-11-01    0.001370
# 2018-12-01    0.001357
# Freq: MS, Length: 97, dtype: float64

# %%
pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred[1:]}).plot();plt.show()

# %% [markdown]
# ## SARIMA model

# %%
#SARIMA model:(p,d,q)(P,D,Q,m)


#p is the number of autoregressive terms,
#d is the number of nonseasonal differences needed for stationarity, and
#q is the number of lagged forecast errors in the prediction equation.

#P: Seasonal autoregressive order.
#D: Seasonal difference order.
#Q: Seasonal moving average order.
#m: The number of time steps for a single seasonal period.

# %%
sarima = sm.tsa.statespace.SARIMAX(train_anomaly,order=(3,1,1),freq='M',seasonal_order=(3,1,1,12),
                                 enforce_stationarity=False, enforce_invertibility=False,).fit()

#sarima.summary()
pred = arima.predict(tr_end,te_end) #[1:]
print('ARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred)))

pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred}).plot();plt.show()
# Out:
# C:\Users\Simo\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA model MSE:0.06644029306089912

# %%
res = sarima.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %%
pred = arima.predict(tr_end,te_end) #[1:]
print('ARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred)))
# Out:
# ARIMA model MSE:0.10398727384504423

# %%
pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred}).plot();plt.show()

# %% [markdown]
# ## SARIMAX-model

# %%
#anomalyrange = glb_formatted['1960-01-01' : '2018-12-01']
#co2range = maunaloaFilled[['CO2filled']]['1960-01-01' : '2018-12-01']

# %%
sarimax = sm.tsa.statespace.SARIMAX(train_anomaly,order=(0,1,1),seasonal_order=(0,1,1,12),exog = train_co2,
                                enforce_stationarity =False, enforce_invertibility=False).fit()
#sarimax.summary()


pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred[1:]}).plot();plt.show()

# %%
sarimax.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                            anomaly   No. Observations:                  612
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood                 294.689
# Date:                            Fri, 15 Feb 2019   AIC                           -581.377
# Time:                                    18:28:41   BIC                           -563.710
# Sample:                                01-01-1960   HQIC                          -574.506
#                                      - 12-01-2010
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CO2filled     -0.0010      0.020     -0.051      0.959      -0.040       0.038
# ma.L1         -0.5934      0.034    -17.266      0.000      -0.661      -0.526
# ma.S.L12      -0.9726      0.034    -28.656      0.000      -1.039      -0.906
# sigma2         0.0204      0.001     17.129      0.000       0.018       0.023
# ===================================================================================
# Ljung-Box (Q):                       51.85   Jarque-Bera (JB):                 1.82
# Prob(Q):                              0.10   Prob(JB):                         0.40
# Heteroskedasticity (H):               1.05   Skew:                             0.10
# Prob(H) (two-sided):                  0.72   Kurtosis:                         3.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
res = sarimax.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %%
from sklearn.metrics import mean_squared_error
pred = sarimax.predict(tr_end,te_end,exog = test_co2)
print('ARIMA model MSE:{}'.format(mean_squared_error(test_anomaly,pred[1:])))
# Out:
# ARIMA model MSE:46.66605076720566

# %%
pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred[1:]}).plot();plt.show()

# %%
len(test_co2)
# Out:
# 96

# %%
sarimax.plot_diagnostics(figsize=(15, 12))

# %%
import itertools
import warnings

# %%
y = train_anomaly

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 4)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False,
                                            exog=train_co2)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:148.06738214543893
# ARIMA(0, 0, 0)x(0, 0, 2, 12)12 - AIC:168.1641325230354
# ARIMA(0, 0, 0)x(0, 0, 3, 12)12 - AIC:-19.66804279665474
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:-368.4937873597595
# ARIMA(0, 0, 0)x(0, 1, 2, 12)12 - AIC:-358.0724498788328
# ARIMA(0, 0, 0)x(0, 1, 3, 12)12 - AIC:-354.67965797048805
# ARIMA(0, 0, 0)x(0, 2, 1, 12)12 - AIC:20.215667146208972
# ARIMA(0, 0, 0)x(0, 2, 2, 12)12 - AIC:-258.8630096523116
# ARIMA(0, 0, 0)x(0, 2, 3, 12)12 - AIC:-252.10863551307472
# ARIMA(0, 0, 0)x(0, 3, 1, 12)12 - AIC:512.4609689511133
# ARIMA(0, 0, 0)x(0, 3, 2, 12)12 - AIC:115.17200818699106
# ARIMA(0, 0, 0)x(0, 3, 3, 12)12 - AIC:107.30342991937903
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:-93.59014134738229
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:-370.74844145405916
# ARIMA(0, 0, 0)x(1, 0, 2, 12)12 - AIC:-353.6283997226131
# ARIMA(0, 0, 0)x(1, 0, 3, 12)12 - AIC:-332.11266419694266
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:-198.24948886566162
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:-366.523615224306
# ARIMA(0, 0, 0)x(1, 1, 2, 12)12 - AIC:-356.6512800882712
# ARIMA(0, 0, 0)x(1, 1, 3, 12)12 - AIC:-352.5418748652736
# ARIMA(0, 0, 0)x(1, 2, 0, 12)12 - AIC:233.26890810788973
# ARIMA(0, 0, 0)x(1, 2, 1, 12)12 - AIC:-162.79847262702395
# ARIMA(0, 0, 0)x(1, 2, 2, 12)12 - AIC:-246.835728366054
# ARIMA(0, 0, 0)x(1, 2, 3, 12)12 - AIC:-257.44048575566904
# ARIMA(0, 0, 0)x(1, 3, 0, 12)12 - AIC:372.29865343878487
# ARIMA(0, 0, 0)x(1, 3, 1, 12)12 - AIC:75.14741420135272
# ARIMA(0, 0, 0)x(1, 3, 2, 12)12 - AIC:83.32871234946
# ARIMA(0, 0, 0)x(1, 3, 3, 12)12 - AIC:11.381140824731965
# ARIMA(0, 0, 0)x(2, 0, 0, 12)12 - AIC:-201.8455341487038
# ARIMA(0, 0, 0)x(2, 0, 1, 12)12 - AIC:-363.0184348009286
# ARIMA(0, 0, 0)x(2, 0, 2, 12)12 - AIC:-361.7038841884819
# ARIMA(0, 0, 0)x(2, 0, 3, 12)12 - AIC:-356.43326439367416
# ARIMA(0, 0, 0)x(2, 1, 0, 12)12 - AIC:-242.7375858711169
# ARIMA(0, 0, 0)x(2, 1, 1, 12)12 - AIC:-362.16198879675414
# ARIMA(0, 0, 0)x(2, 1, 2, 12)12 - AIC:-360.6089372465467
# ARIMA(0, 0, 0)x(2, 1, 3, 12)12 - AIC:-348.81291686924584
# ARIMA(0, 0, 0)x(2, 2, 0, 12)12 - AIC:67.18447282801492
# ARIMA(0, 0, 0)x(2, 2, 1, 12)12 - AIC:-205.0258266598597
# ARIMA(0, 0, 0)x(2, 2, 2, 12)12 - AIC:-255.03952035145716
# ARIMA(0, 0, 0)x(2, 2, 3, 12)12 - AIC:-256.79394139796625
# ARIMA(0, 0, 0)x(2, 3, 0, 12)12 - AIC:282.9893939450718
# ARIMA(0, 0, 0)x(2, 3, 1, 12)12 - AIC:82.08597837355282
# ARIMA(0, 0, 0)x(2, 3, 2, 12)12 - AIC:72.54991924708952
# ARIMA(0, 0, 0)x(2, 3, 3, 12)12 - AIC:-1.9239234674551255
# ARIMA(0, 0, 0)x(3, 0, 0, 12)12 - AIC:-235.33311311982828
# ARIMA(0, 0, 0)x(3, 0, 1, 12)12 - AIC:-296.3199972279506
# ARIMA(0, 0, 0)x(3, 0, 2, 12)12 - AIC:-347.3166320600965
# ARIMA(0, 0, 0)x(3, 0, 3, 12)12 - AIC:-354.60102088600144
# ARIMA(0, 0, 0)x(3, 1, 0, 12)12 - AIC:-258.0631545517817
# ARIMA(0, 0, 0)x(3, 1, 1, 12)12 - AIC:-348.12125397592496
# ARIMA(0, 0, 0)x(3, 1, 2, 12)12 - AIC:-351.9877601599852
# ARIMA(0, 0, 0)x(3, 1, 3, 12)12 - AIC:-339.199856428682
# ARIMA(0, 0, 0)x(3, 2, 0, 12)12 - AIC:-60.70961166742158
# ARIMA(0, 0, 0)x(3, 2, 1, 12)12 - AIC:-219.5110417842356
# ARIMA(0, 0, 0)x(3, 2, 2, 12)12 - AIC:-218.98876630710808
# ARIMA(0, 0, 0)x(3, 2, 3, 12)12 - AIC:-217.91820948400422
# ARIMA(0, 0, 0)x(3, 3, 0, 12)12 - AIC:242.36359630418946
# ARIMA(0, 0, 0)x(3, 3, 1, 12)12 - AIC:68.11092283150066
# ARIMA(0, 0, 0)x(3, 3, 2, 12)12 - AIC:-23.809495780389355
# ARIMA(0, 0, 0)x(3, 3, 3, 12)12 - AIC:51.69678166792649
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:15.43552514070678
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:-111.75478035290254
# ARIMA(0, 0, 1)x(0, 0, 2, 12)12 - AIC:-170.34868819106566
# ARIMA(0, 0, 1)x(0, 0, 3, 12)12 - AIC:-214.11013062008774
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:-127.98053622072445
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:-488.8189776853223
# ARIMA(0, 0, 1)x(0, 1, 2, 12)12 - AIC:-475.42653437038746
# ARIMA(0, 0, 1)x(0, 1, 3, 12)12 - AIC:-469.0709458522666
# ARIMA(0, 0, 1)x(0, 2, 0, 12)12 - AIC:531.6848375761299
# ARIMA(0, 0, 1)x(0, 2, 1, 12)12 - AIC:-73.02253169372906
# ARIMA(0, 0, 1)x(0, 2, 2, 12)12 - AIC:-372.71874493468476
# ARIMA(0, 0, 1)x(0, 2, 3, 12)12 - AIC:-361.32305408627985
# ARIMA(0, 0, 1)x(0, 3, 0, 12)12 - AIC:1073.6126379985062
# ARIMA(0, 0, 1)x(0, 3, 1, 12)12 - AIC:435.1618252018876
# ARIMA(0, 0, 1)x(0, 3, 2, 12)12 - AIC:47.88531463332376
# ARIMA(0, 0, 1)x(0, 3, 3, 12)12 - AIC:37.5234122471337
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:-239.72262011339535
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:-488.00329941302937
# ARIMA(0, 0, 1)x(1, 0, 2, 12)12 - AIC:-478.1868475418149
# ARIMA(0, 0, 1)x(1, 0, 3, 12)12 - AIC:-461.31090229113806
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:-318.53874504717317
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:-488.03962535606945
# ARIMA(0, 0, 1)x(1, 1, 2, 12)12 - AIC:-472.2749294723656
# ARIMA(0, 0, 1)x(1, 1, 3, 12)12 - AIC:-466.9761971949605
# ARIMA(0, 0, 1)x(1, 2, 0, 12)12 - AIC:134.83740656214457
# ARIMA(0, 0, 1)x(1, 2, 1, 12)12 - AIC:-266.49521494550544
# ARIMA(0, 0, 1)x(1, 2, 2, 12)12 - AIC:-360.81653120335324
# ARIMA(0, 0, 1)x(1, 2, 3, 12)12 - AIC:-367.5868495114684
# ARIMA(0, 0, 1)x(1, 3, 0, 12)12 - AIC:289.62105337759556
# ARIMA(0, 0, 1)x(1, 3, 1, 12)12 - AIC:7.0617988793396265
# ARIMA(0, 0, 1)x(1, 3, 2, 12)12 - AIC:12.780244749354955
# ARIMA(0, 0, 1)x(1, 3, 3, 12)12 - AIC:7.017450059452045
# ARIMA(0, 0, 1)x(2, 0, 0, 12)12 - AIC:-340.99170193396424
# ARIMA(0, 0, 1)x(2, 0, 1, 12)12 - AIC:-482.5416084533401
# ARIMA(0, 0, 1)x(2, 0, 2, 12)12 - AIC:-484.890257066902
# ARIMA(0, 0, 1)x(2, 0, 3, 12)12 - AIC:-461.755832043199
# ARIMA(0, 0, 1)x(2, 1, 0, 12)12 - AIC:-356.98980905015117
# ARIMA(0, 0, 1)x(2, 1, 1, 12)12 - AIC:-476.69188276864566
# ARIMA(0, 0, 1)x(2, 1, 2, 12)12 - AIC:-475.41781451964266
# ARIMA(0, 0, 1)x(2, 1, 3, 12)12 - AIC:-462.02913059720595
# ARIMA(0, 0, 1)x(2, 2, 0, 12)12 - AIC:-24.61151871387859
# ARIMA(0, 0, 1)x(2, 2, 1, 12)12 - AIC:-306.20422817196345
# ARIMA(0, 0, 1)x(2, 2, 2, 12)12 - AIC:-359.78910925847606
# ARIMA(0, 0, 1)x(2, 2, 3, 12)12 - AIC:-364.04324982408514
# ARIMA(0, 0, 1)x(2, 3, 0, 12)12 - AIC:207.1229363578176
# ARIMA(0, 0, 1)x(2, 3, 1, 12)12 - AIC:13.708150288316409
# ARIMA(0, 0, 1)x(2, 3, 2, 12)12 - AIC:3.577863190356725
# ARIMA(0, 0, 1)x(2, 3, 3, 12)12 - AIC:9.304753562961611
# ARIMA(0, 0, 1)x(3, 0, 0, 12)12 - AIC:-361.6464345674217
# ARIMA(0, 0, 1)x(3, 0, 1, 12)12 - AIC:-457.9504947141779
# ARIMA(0, 0, 1)x(3, 0, 2, 12)12 - AIC:-470.36097996854414
# ARIMA(0, 0, 1)x(3, 0, 3, 12)12 - AIC:-471.2337323960792
# ARIMA(0, 0, 1)x(3, 1, 0, 12)12 - AIC:-369.24292888969603
# ARIMA(0, 0, 1)x(3, 1, 1, 12)12 - AIC:-459.8727872499169
# ARIMA(0, 0, 1)x(3, 1, 2, 12)12 - AIC:-463.2508328342685
# ARIMA(0, 0, 1)x(3, 1, 3, 12)12 - AIC:-456.0387365351869
# ARIMA(0, 0, 1)x(3, 2, 0, 12)12 - AIC:-136.78247653553237
# ARIMA(0, 0, 1)x(3, 2, 1, 12)12 - AIC:-318.02332469827
# ARIMA(0, 0, 1)x(3, 2, 2, 12)12 - AIC:-316.1532581372488
# ARIMA(0, 0, 1)x(3, 2, 3, 12)12 - AIC:-356.61484343336826
# ARIMA(0, 0, 1)x(3, 3, 0, 12)12 - AIC:176.25263718795983
# ARIMA(0, 0, 1)x(3, 3, 1, 12)12 - AIC:3.2992041827619154
# ARIMA(0, 0, 1)x(3, 3, 2, 12)12 - AIC:-97.17948140073071
# ARIMA(0, 0, 1)x(3, 3, 3, 12)12 - AIC:-13.133732416615587
# ARIMA(0, 0, 2)x(0, 0, 0, 12)12 - AIC:-242.72233992475304
# ARIMA(0, 0, 2)x(0, 0, 1, 12)12 - AIC:-291.6155375781868
# ARIMA(0, 0, 2)x(0, 0, 2, 12)12 - AIC:-340.1582820258185
# ARIMA(0, 0, 2)x(0, 0, 3, 12)12 - AIC:-354.9167525498555
# ARIMA(0, 0, 2)x(0, 1, 0, 12)12 - AIC:-206.1656768711631
# ARIMA(0, 0, 2)x(0, 1, 1, 12)12 - AIC:-568.8539150912527
# ARIMA(0, 0, 2)x(0, 1, 2, 12)12 - AIC:-552.4398365955576
# ARIMA(0, 0, 2)x(0, 1, 3, 12)12 - AIC:-540.6597589253338
# ARIMA(0, 0, 2)x(0, 2, 0, 12)12 - AIC:462.4553214473181
# ARIMA(0, 0, 2)x(0, 2, 1, 12)12 - AIC:-143.50835189595014
# ARIMA(0, 0, 2)x(0, 2, 2, 12)12 - AIC:-447.8021573928543
# ARIMA(0, 0, 2)x(0, 2, 3, 12)12 - AIC:-432.6741222955951
# ARIMA(0, 0, 2)x(0, 3, 0, 12)12 - AIC:1013.2936905237414
# ARIMA(0, 0, 2)x(0, 3, 1, 12)12 - AIC:376.5513352992823
# ARIMA(0, 0, 2)x(0, 3, 2, 12)12 - AIC:-8.99678864878765
# ARIMA(0, 0, 2)x(0, 3, 3, 12)12 - AIC:-22.132236761822014
# ARIMA(0, 0, 2)x(1, 0, 0, 12)12 - AIC:-357.7364571598399
# ARIMA(0, 0, 2)x(1, 0, 1, 12)12 - AIC:-572.0785421029348
# ARIMA(0, 0, 2)x(1, 0, 2, 12)12 - AIC:-545.4858031397137
# ARIMA(0, 0, 2)x(1, 0, 3, 12)12 - AIC:-540.2015915555207
# ARIMA(0, 0, 2)x(1, 1, 0, 12)12 - AIC:-401.57942834559526
# ARIMA(0, 0, 2)x(1, 1, 1, 12)12 - AIC:-560.6948581975514
# ARIMA(0, 0, 2)x(1, 1, 2, 12)12 - AIC:-553.0912418455825
# ARIMA(0, 0, 2)x(1, 1, 3, 12)12 - AIC:-539.72738233272
# ARIMA(0, 0, 2)x(1, 2, 0, 12)12 - AIC:62.661410290416065
# ARIMA(0, 0, 2)x(1, 2, 1, 12)12 - AIC:-344.34192513698207
# ARIMA(0, 0, 2)x(1, 2, 2, 12)12 - AIC:-445.8019340551048
# ARIMA(0, 0, 2)x(1, 2, 3, 12)12 - AIC:-441.9413446957068
# ARIMA(0, 0, 2)x(1, 3, 0, 12)12 - AIC:218.50382322644862
# ARIMA(0, 0, 2)x(1, 3, 1, 12)12 - AIC:-53.73569071273127
# ARIMA(0, 0, 2)x(1, 3, 2, 12)12 - AIC:-52.5061775876797
# ARIMA(0, 0, 2)x(1, 3, 3, 12)12 - AIC:-114.66611639531098
# ARIMA(0, 0, 2)x(2, 0, 0, 12)12 - AIC:-443.62166861608205
# ARIMA(0, 0, 2)x(2, 0, 1, 12)12 - AIC:-519.5197398817448
# ARIMA(0, 0, 2)x(2, 0, 2, 12)12 - AIC:-563.7931197257092
# ARIMA(0, 0, 2)x(2, 0, 3, 12)12 - AIC:-547.2709041948867
# ARIMA(0, 0, 2)x(2, 1, 0, 12)12 - AIC:-441.3763231085335
# ARIMA(0, 0, 2)x(2, 1, 1, 12)12 - AIC:-553.2022793998358
# ARIMA(0, 0, 2)x(2, 1, 2, 12)12 - AIC:-555.1408100267647
# ARIMA(0, 0, 2)x(2, 1, 3, 12)12 - AIC:-537.5029397512656
# ARIMA(0, 0, 2)x(2, 2, 0, 12)12 - AIC:-87.77091144016761
# ARIMA(0, 0, 2)x(2, 2, 1, 12)12 - AIC:-379.1127248262866
# ARIMA(0, 0, 2)x(2, 2, 2, 12)12 - AIC:-434.39526548888574
# ARIMA(0, 0, 2)x(2, 2, 3, 12)12 - AIC:-439.8792883999263
# ARIMA(0, 0, 2)x(2, 3, 0, 12)12 - AIC:143.68187796545624
# ARIMA(0, 0, 2)x(2, 3, 1, 12)12 - AIC:-48.06877170666494
# ARIMA(0, 0, 2)x(2, 3, 2, 12)12 - AIC:-58.806666439584134
# ARIMA(0, 0, 2)x(2, 3, 3, 12)12 - AIC:-51.40197417158595
# ARIMA(0, 0, 2)x(3, 0, 0, 12)12 - AIC:-459.35867019803266
# ARIMA(0, 0, 2)x(3, 0, 1, 12)12 - AIC:-486.9367953469395
# ARIMA(0, 0, 2)x(3, 0, 2, 12)12 - AIC:-541.557399402018
# ARIMA(0, 0, 2)x(3, 0, 3, 12)12 - AIC:-546.1315719939244
# ARIMA(0, 0, 2)x(3, 1, 0, 12)12 - AIC:-455.15658151650075
# ARIMA(0, 0, 2)x(3, 1, 1, 12)12 - AIC:-541.3335268230082
# ARIMA(0, 0, 2)x(3, 1, 2, 12)12 - AIC:-538.7822486231948
# ARIMA(0, 0, 2)x(3, 1, 3, 12)12 - AIC:-530.2504050748021
# ARIMA(0, 0, 2)x(3, 2, 0, 12)12 - AIC:-196.61540921763032
# ARIMA(0, 0, 2)x(3, 2, 1, 12)12 - AIC:-393.7326756668472
# ARIMA(0, 0, 2)x(3, 2, 2, 12)12 - AIC:-405.97539963897214
# ARIMA(0, 0, 2)x(3, 2, 3, 12)12 - AIC:-420.82656387074553
# ARIMA(0, 0, 2)x(3, 3, 0, 12)12 - AIC:118.67344566333438
# ARIMA(0, 0, 2)x(3, 3, 1, 12)12 - AIC:-59.35550281255294
# ARIMA(0, 0, 2)x(3, 3, 3, 12)12 - AIC:-70.6784748041012
# ARIMA(0, 0, 3)x(0, 0, 0, 12)12 - AIC:-328.7839639681565
# ARIMA(0, 0, 3)x(0, 0, 1, 12)12 - AIC:-360.1080072604143
# ARIMA(0, 0, 3)x(0, 0, 2, 12)12 - AIC:-395.0842272206794
# ARIMA(0, 0, 3)x(0, 0, 3, 12)12 - AIC:-398.91551181477143
# ARIMA(0, 0, 3)x(0, 1, 0, 12)12 - AIC:-224.40758793807709
# ARIMA(0, 0, 3)x(0, 1, 1, 12)12 - AIC:-578.156343087596
# ARIMA(0, 0, 3)x(0, 1, 2, 12)12 - AIC:-562.6435647412254
# ARIMA(0, 0, 3)x(0, 1, 3, 12)12 - AIC:-548.8591914951633
# ARIMA(0, 0, 3)x(0, 2, 0, 12)12 - AIC:440.9486095996583
# ARIMA(0, 0, 3)x(0, 2, 1, 12)12 - AIC:-162.37898551494123
# ARIMA(0, 0, 3)x(0, 2, 2, 12)12 - AIC:-456.5147306795489
# ARIMA(0, 0, 3)x(0, 2, 3, 12)12 - AIC:-442.84689696247233
# ARIMA(0, 0, 3)x(0, 3, 0, 12)12 - AIC:995.7432140086862
# ARIMA(0, 0, 3)x(0, 3, 1, 12)12 - AIC:359.01991183138364
# ARIMA(0, 0, 3)x(0, 3, 2, 12)12 - AIC:-23.399807290611697
# ARIMA(0, 0, 3)x(0, 3, 3, 12)12 - AIC:-32.12004449106583
# ARIMA(0, 0, 3)x(1, 0, 0, 12)12 - AIC:-406.7361323683929
# ARIMA(0, 0, 3)x(1, 0, 1, 12)12 - AIC:-582.7157141925927
# ARIMA(0, 0, 3)x(1, 0, 2, 12)12 - AIC:-535.2118898518861

# %%
#sarima = sm.tsa.statespace.SARIMAX(train_anomaly,order=(0,1,1),seasonal_order=(0,0,1,12),exog=train_co2,
#                                enforce_stationarity =False, enforce_invertibility=False).fit()

#ARIMA(0, 0, 2)x(1, 0, 1, 12)12 - AIC:-572.0785421029348
#ARIMA(0, 0, 3)x(0, 1, 1, 12)12 - AIC:-578.156343087596
#ARIMA(0, 0, 3)x(1, 0, 1, 12)12 - AIC:-582.7157141925927

sarima = sm.tsa.statespace.SARIMAX(train_anomaly,order=(0,1,1),seasonal_order=(0,0,1,12),exog=train_co2,
                                enforce_stationarity =False, enforce_invertibility=False).fit()

# %%
pred = sarima.predict(tr_end,te_end,exog=test_co2)
len(pred)
# Out:
# 97

# %%
len(pred)
# Out:
# 97

# %%
pd.DataFrame({'test':test_anomaly.values.flatten(),'pred':pred[1:]}).plot();plt.show()

# %%
test_co2
# Out:
#             anomaly
# DateTime
# 2011-01-01     0.72
# 2011-02-01     0.69
# 2011-03-01     0.77
# 2011-04-01     0.83
# 2011-05-01     0.66
# 2011-06-01     0.74
# 2011-07-01     0.91
# 2011-08-01     0.97
# 2011-09-01     0.78
# 2011-10-01     0.83
# 2011-11-01     0.79
# 2011-12-01     0.80
# 2012-01-01     0.61
# 2012-02-01     0.58
# 2012-03-01     0.70
# 2012-04-01     0.80
# 2012-05-01     0.94
# 2012-06-01     0.72
# 2012-07-01     0.56
# 2012-08-01     0.86
# 2012-09-01     0.88
# 2012-10-01     0.91
# 2012-11-01     0.93
# 2012-12-01     0.71
# 2013-01-01     0.97
# 2013-02-01     0.74
# 2013-03-01     0.84
# 2013-04-01     0.67
# 2013-05-01     0.66
# 2013-06-01     0.88
# ...             ...
# 2016-07-01     0.97
# 2016-08-01     1.33
# 2016-09-01     1.10
# 2016-10-01     1.22
# 2016-11-01     1.20
# 2016-12-01     1.14
# 2017-01-01     1.15
# 2017-02-01     1.43
# 2017-03-01     1.39
# 2017-04-01     1.16
# 2017-05-01     1.24
# 2017-06-01     0.78
# 2017-07-01     1.09
# 2017-08-01     1.11
# 2017-09-01     0.97
# 2017-10-01     1.17
# 2017-11-01     1.06
# 2017-12-01     1.16
# 2018-01-01     1.04
# 2018-02-01     1.16
# 2018-03-01     1.22
# 2018-04-01     1.21
# 2018-05-01     1.02
# 2018-06-01     0.87
# 2018-07-01     1.07
# 2018-08-01     0.92
# 2018-09-01     0.92
# 2018-10-01     1.12
# 2018-11-01     0.98
# 2018-12-01     1.23
#
# [96 rows x 1 columns]
